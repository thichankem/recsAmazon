# %%
import numpy as np
import pandas as pd
import pickle
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity

# %%
RATINGS_CSV = '../preprocessing/preprocessed_Cell_Phones_and_Accessories.csv'
META_CSV    = '../preprocessing/preprocessed_meta_preprocessedCell_Phones_and_Accessories.csv'
OUTPUT_PKL  = 'collaborative_model.pkl'

chunks = []
for chunk in pd.read_csv(RATINGS_CSV, usecols=['user_id', 'parent_asin', 'rating'], dtype={'rating': 'int8'}, chunksize=500_000):
    chunks.append(chunk)

df = pd.concat(chunks, ignore_index=True)
# Out:
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 500,000 dòng
#   Đọc chunk: 160,000 dòng
# Tổng cộng: 10,160,000 ratings

# %%
for i in range(3):
    n = len(df)
    user_cnt = df['user_id'].value_counts()
    item_cnt = df['parent_asin'].value_counts()
    df = df[
        df['user_id'].isin(user_cnt[user_cnt >= 10].index) &
        df['parent_asin'].isin(item_cnt[item_cnt >= 10].index)
    ]

df = df.drop_duplicates(subset=['user_id', 'parent_asin'], keep='last')
# Out:
# Lần 1: 10,160,000 → 960,258 ratings
# Lần 2: 960,258 → 482,956 ratings
# Lần 3: 482,956 → 240,658 ratings
# Sau dedup: 233,371 ratings

# %%
all_users = df['user_id'].unique()
all_items = df['parent_asin'].unique()

user_to_idx = {u: i for i, u in enumerate(all_users)}
item_to_idx = {it: i for i, it in enumerate(all_items)}
idx_to_item = {i: it for it, i in item_to_idx.items()}

n_users = len(all_users)
n_items = len(all_items)

user_col = df['user_id'].map(user_to_idx).to_numpy(dtype=np.int32)
item_col = df['parent_asin'].map(item_to_idx).to_numpy(dtype=np.int32)
rate_col = df['rating'].to_numpy(dtype=np.float32)

df_meta = (pd.read_csv(META_CSV, usecols=['parent_asin', 'title'], dtype=str)
             .drop_duplicates(subset=['parent_asin']))
title_map = dict(zip(df_meta['parent_asin'], df_meta['title'].fillna('')))
item_titles = [title_map.get(all_items[i], all_items[i]) for i in range(n_items)]

del df, df_meta
# Out:
# Users: 19,292  |  Items: 16,413

# %%
mu = np.zeros(n_users, dtype=np.float32)
for u in range(n_users):
    mask = (user_col == u)
    if mask.any():
        mu[u] = rate_col[mask].mean()

rate_norm = rate_col - mu[user_col]

Ybar = sparse.csr_matrix(
    (rate_norm, (item_col, user_col)),
    shape=(n_items, n_users),
    dtype=np.float32
)
# Out:
# Ybar shape: (16413, 19292)  |  non-zeros: 233,371

# %%
BATCH = 500  

S = np.zeros((n_items, n_items), dtype=np.float32)

for start in range(0, n_items, BATCH):
    end = min(start + BATCH, n_items)
    S[start:end] = cosine_similarity(Ybar[start:end], Ybar).astype(np.float32)
# Out:
#   16,413 / 16,413 (100%)
# S shape: (16413, 16413)

# %%
model_data = {
    'user_to_idx':  user_to_idx,  
    'item_to_idx':  item_to_idx,  
    'idx_to_item':  idx_to_item,   
    'item_ids':     all_items,  
    'item_titles':  item_titles,  

    'cf_S':    S,     
    'cf_mu':   mu,     
    'cf_k':    10,   

    'Y_data':  np.column_stack([user_col, item_col, rate_col]),
}

with open(OUTPUT_PKL, 'wb') as f:
    pickle.dump(model_data, f, protocol=4)

import os
mb = os.path.getsize(OUTPUT_PKL) / 1024**2
# Out:
# ✅ Đã lưu: collaborative_model.pkl (1036 MB)

# %%
def recommend(viewed_item_indices, top_k=10):
    """
    viewed_item_indices: list[int] – index của các item đã xem
    Trả về top_k item gợi ý (title) chưa xem
    """
    agg = np.zeros(n_items, dtype=np.float32)

    for i in viewed_item_indices:
        row = S[i].copy()
        # Giữ top-10 neighbor của item i
        topk_idx = np.argpartition(row, -10)[-10:]
        mask = np.zeros_like(row)
        mask[topk_idx] = row[topk_idx]
        agg += mask

    # Loại trừ item đã xem
    agg[viewed_item_indices] = -np.inf

    ranked = np.argsort(agg)[::-1][:top_k]
    return [item_titles[i] for i in ranked]


# Người dùng đã xem 3 sản phẩm đầu tiên
sample_viewed = [0, 1, 2]
print('Đã xem:')
for i in sample_viewed:
    print(f'  - {item_titles[i][:70]}')

print('\nGợi ý:')
for i, r in enumerate(recommend(sample_viewed), 1):
    print(f'  {i:2}. {r[:70]}')
# Out:
# Đã xem:
#   - Yacig Capacitive Stylus Pen, 4-in-1 High Sensitivity and Precision Tou
#   - Goton [3 Pack] Bling Case Compatible with Samsung Galaxy Watch 4 Scree
#   - Tensea [4+4Pcs] for Samsung Galaxy Watch 4 2021 & 5 2022 Screen Protec
#
# Gợi ý:
#    1. iPhone 6s Plus Case, [Armorbox] i-Blason Built-in [Screen Protector] H
#    2. Sprint HTC Evo 4G Android Cell Phone (Black), Without Contract
#    3. [2 Pack] Privacy Screen Protector for iPhone SE 2022 3rd Generation/iP
#    4. Phone Ring Stand Holder 4 Package Finger Grip Stand Holder Ring, 360°R
#    5. Galaxy Note 8 Case, Hocase Shockproof Heavy Duty Hybrid Silicone Rubbe
#    6. Tech Armor Ballistic Glass Screen Protector Designed for Apple NEW iPh
#    7. Maledan Compatible with Fitbit Versa 3 Bands/Fitbit Sense Bands, Fadel
#    8. GoDonut Original Phone Stand - Portable Mount Accessory for Travel, Ni
#    9. ZXCASD Metal Bands Compatible with Apple Watch Band 38mm 40mm 41mm Wom
#   10. OTAO Galaxy S9 Plus Screen Protector Tempered Glass, [Update Version]
